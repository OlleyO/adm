# %% [markdown]
# # Видобування даних
# # Лабораторна робота №1 : Розуміння задачі і області застосування

# %%
Селіванов О.О. Student Grade Prediction(https://www.kaggle.com/datasets/dipam7/student-grade-prediction)

# %% [markdown]
# Вибір та обгрунтування набору даних. Фаза Business understanding за СRISP-DM.

# %% [markdown]
# Перша лабораторна робота призначена для обрання та мотивації обраного набору даних. Основними вимогами є:
#
#
# *   Табличне представлення даних (не зображення або часовий ряд)
# *   Мінімум 250 записів - чим краще тим більше , в рамках розумного (менша кількість записів можлива але обговорювана)
# *   Мінімум 4 колонки з даними по яким можна буде виконувати аналіз / моделювання і візуалізацію (колонки типу ID, номер або службові не рахуються)
# * Один варіант набору даних на групу

# %% [markdown]
# 1. Який набір даних ви обрали ?
# Я обрав Student Grade Prediction(Прогнозування балів студентів), містить дані про академічну успішність студентів двох португальських шкіл. Містить інформацію про оцінки учнів, їхні демографічні, соціальні дані, а також дані, що пов'язані зі школою. Дані стосуються успішності в двох дисциплінах: португальська мова та математика.

# %% [markdown]
# 2. Які у вас ідеї / теорії / припущення що у вибраному домені можна покращити з аналізом та видобуванням даних?
# Можна визначити, як певні демографічні та соціальні умови впливають на оцінки студентів, дасть зрозуміти, що має найбільший вплив на успішність, як академічну успішність можна покращити.

# %% [markdown]
# 3. Які проблеми є у області з якої ви взяли дані ? Що є "bottleneck" у даному напрямі, що можна автоматизувати ?
# Вплив статі на успішність, гендерна нерівність, вплив особистого життя на успішність, в теорії, маючи певні показники, можна буде автоматизувати процес виявлення причини поганої академічної успішності або процес створення підстав для перевірки на академічну доброчесність студента, якщо його бал не збігається з прогнозом.

# %% [markdown]
# 4. Що за ризики / складності ви припускаєте можуть очікувати вас в процесі роботи з даними ?
# Оскільки фінальна оцінка за рік сильно корельована з оцінками за перший та другий семестр, може бути важко спрогнозувати її без оцінок за семестри.

# %% [markdown]
# 5. В рамках добування даних яким методом ваша проблема або ідея може бути вирішена ? (кластеризація, прогнозування, класифікація)
# Прогнозування та кластеризація.
